# %% [markdown]
# Pseudocode for the pokemon battle game
#
# #Creating pokemons for user to select
#
# pokemon1 = {'attack1' : 'damage1'
#             'attack2' : 'damage2'
#             'attack3' : 'damage3'
#             'attack4' : 'damage4'}
#
#
# pokemon2 = {'attack1' : 'damage1'
#             'attack2' : 'damage2'
#             'attack3' : 'damage3'
#             'attack4' : 'damage4'}
#
#
# pokemon3 = {'attack1' : 'damage1'
#             'attack2' : 'damage2'
#             'attack3' : 'damage3'
#             'attack4' : 'damage4'}
#
#
# user_pokemon = whatever he choses
# computer_pokemon = randomly picked
#
# user_hp = 100
# computer_hp = 100
#
#
#
#
# #Create a function for the battle
#
# def battle_user( )
#     Attack selection module : the user input the attack he wants to use
#     Damage calculation module : we need to reach the damage value of the attack in the dict
#                                 then computer_hp = computer_hp - chosed attack value
#
#
# def battle_computer( )
#     Attack selection module : randomly chose one attack from the dict
#     Damage calculation module : we need to reach the damage value of the attack in the dict
#                                 then user_hp = user_hp - chosed attack value
#
# def end_of_turn( )
#     print("Your current hp is: ",user_hp)
#     print("Computer current hp is: ",computer_hp)
#
#
# #Code
# counter = 1
#
# while user_hp > 0 and computer_hp > 0:
#          if counter is odd:
#              battle_computer( )  #means computer plays first
#              end_of_turn( )
#          elif counter is even:
#              battle_user( )     #means user plays first
#              end_of_turn( )
#
#          counter += 1
#
#
# if user_hp < 0:
#     print("You won")
# else:
#     print("You lose")
